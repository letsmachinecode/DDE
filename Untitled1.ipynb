# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('csv/alsecure.csv')

# %%
data.shape
# Out:
# (591, 52)

# %%
data_1=pd.read_csv('updated_csv/alsecure.csv')

# %%
data_1.shape
# Out:
# (621, 82)

# %%
data.head()
# Out:
#    pgNo  startX  startY    endX   endY       w      h  fntSize  txtColor  \
# 0     1   74.85   69.78  158.84  80.26   83.99  10.48  14.6832 -16777216
# 1     1  163.85   69.78  175.59  80.26   11.74  10.48  14.6832 -16777216
# 2     1  180.53   69.78  283.82  80.26  103.29  10.48  14.6832 -16777216
# 3     1  288.77   69.78  368.10  80.26   79.33  10.48  14.6832 -16777216
# 4     1  378.07   69.78  432.12  80.26   54.05  10.48  14.6832 -16777216
#
#                  txtFnt  ... Right_fntSize  Right_txtColor  \
# 0  BookmanOldStyle-Bold  ...       14.6832     -16777216.0
# 1  BookmanOldStyle-Bold  ...       14.6832     -16777216.0
# 2  BookmanOldStyle-Bold  ...       14.6832     -16777216.0
# 3  BookmanOldStyle-Bold  ...       14.6832     -16777216.0
# 4  BookmanOldStyle-Bold  ...       14.6832     -16777216.0
#
#            Right_txtFnt  Right_topMargin  Right_bottomMargin  \
# 0  BookmanOldStyle-Bold            69.78              711.74
# ...

# %%
data.tail()
# Out:
#      pgNo  startX  startY    endX    endY      w     h  fntSize  txtColor  \
# 586     3  451.20  774.80  480.21  780.00  29.01  5.20      9.0 -16777216
# 587     3  483.84  773.07  487.73  777.12   3.89  4.05      7.0 -16777216
# 588     3  490.56  774.13  504.74  779.04  14.18  4.91      8.5 -16777216
# 589     3  508.32  774.22  520.83  778.56  12.51  4.34      7.5 -16777216
# 590     3  544.32  779.77  583.42  789.60  39.10  9.83     17.0 -16777216
#
#         txtFnt  ... Right_fntSize  Right_txtColor  Right_txtFnt  \
# 586  Helvetica  ...           7.0     -16777216.0     Helvetica
# 587  Helvetica  ...           8.5     -16777216.0     Helvetica
# 588  Helvetica  ...           7.5     -16777216.0     Helvetica
# 589  Helvetica  ...          17.0     -16777216.0     Helvetica
# 590  Helvetica  ...           NaN             NaN           NaN
#
#      Right_topMargin  Right_bottomMargin  Right_leftMargin  Right_rightMargin  \
# ...

# %%
data['label']='undefined'

# %%
data
# Out:
#      pgNo  startX  startY    endX    endY       w      h  fntSize  txtColor  \
# 0       1   74.85   69.78  158.84   80.26   83.99  10.48  14.6832 -16777216
# 1       1  163.85   69.78  175.59   80.26   11.74  10.48  14.6832 -16777216
# 2       1  180.53   69.78  283.82   80.26  103.29  10.48  14.6832 -16777216
# 3       1  288.77   69.78  368.10   80.26   79.33  10.48  14.6832 -16777216
# 4       1  378.07   69.78  432.12   80.26   54.05  10.48  14.6832 -16777216
# ..    ...     ...     ...     ...     ...     ...    ...      ...       ...
# 586     3  451.20  774.80  480.21  780.00   29.01   5.20   9.0000 -16777216
# 587     3  483.84  773.07  487.73  777.12    3.89   4.05   7.0000 -16777216
# 588     3  490.56  774.13  504.74  779.04   14.18   4.91   8.5000 -16777216
# 589     3  508.32  774.22  520.83  778.56   12.51   4.34   7.5000 -16777216
# 590     3  544.32  779.77  583.42  789.60   39.10   9.83  17.0000 -16777216
#
# ...

# %%
data.shape
# Out:
# (591, 53)
